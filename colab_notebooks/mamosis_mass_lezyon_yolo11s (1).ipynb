# %%
# check assigned GPU, T4 expected
# atanan GPU kontrolu, T4 bekleniyor
# !nvidia-smi --query-gpu=name,memory.total --format=csv,noheader
# Out:
# Tesla T4, 15360 MiB

# %%
# install ultralytics
# ultralytics kurulumu
# !pip install -q ultralytics openpyxl
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.98 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.7/235.7 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

# dataset root, same as exploration notebook
# veri seti koku, kesif notebook ile ayni
DATASET_ROOT = '/content/drive/MyDrive/Kitle-Vindr&Tekno'

# this model's own Drive folder
# bu modelin kendi Drive klasoru
MODEL_NAME = 'yolo11s'
MODEL_DIR = f'/content/drive/MyDrive/mass_detection/{MODEL_NAME}'
Path(MODEL_DIR).mkdir(parents=True, exist_ok=True)

# key output paths
# ana cikti yollari
EXCEL_LOG = f'{MODEL_DIR}/{MODEL_NAME}_log.xlsx'
DATA_YAML = f'{MODEL_DIR}/mass_data.yaml'

assert Path(DATASET_ROOT).is_dir(), f'Yol yok: {DATASET_ROOT}'
print('Dataset:', DATASET_ROOT)
print('Model dir:', MODEL_DIR)
# Out:
# Dataset: /content/drive/MyDrive/Kitle-Vindr&Tekno
# Model dir: /content/drive/MyDrive/mass_detection/yolo11s

# %%
import yaml

# single class mass detection config
# tek sinif kutle tespiti ayari
data_cfg = {
    'path': DATASET_ROOT,
    'train': 'train/images',
    'val': 'val/images',
    'test': 'test/images',
    'nc': 1,
    'names': ['mass'],
}
with open(DATA_YAML, 'w') as f:
    yaml.safe_dump(data_cfg, f, sort_keys=False)
print('data.yaml yazildi:', DATA_YAML)
# Out:
# data.yaml yazildi: /content/drive/MyDrive/mass_detection/yolo11s/mass_data.yaml

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# standard metric schema, identical for all three models
# standart metrik semasi, uc model icin ayni
SCHEMA = ["epoch", "train_loss", "val_loss", "precision", "recall", "mAP50", "mAP50_95", "f1"]


def compute_f1(precision, recall):
    # F1 from precision and recall, safe against zero division
    # precision ve recall'dan F1, sifira bolmeye karsi guvenli
    if precision is None or recall is None:
        return None
    denom = precision + recall
    if denom <= 0:
        return 0.0
    return 2 * precision * recall / denom


def append_epoch_row(excel_path, row, resume_epoch=None):
    # append one epoch row to the Excel log, keep standard schema
    # bir epoch satirini Excel loguna ekle, standart semayi koru
    # on resume, drop rows at or after resume_epoch to avoid duplicates
    # resume'da tekrari onlemek icin resume_epoch ve sonrasini at
    if os.path.exists(excel_path):
        df = pd.read_excel(excel_path)
        if resume_epoch is not None:
            df = df[df["epoch"] < resume_epoch]
        rows = df.to_dict("records")
    else:
        rows = []
    clean = {k: row.get(k, None) for k in SCHEMA}
    rows.append(clean)
    pd.DataFrame(rows)[SCHEMA].to_excel(excel_path, index=False)
    return len(rows)


def plot_training_curves(excel_path, out_path, model_name):
    # draw the 4 required curves: loss, mAP, precision, recall
    # istenen 4 egriyi ciz: loss, mAP, precision, recall
    # same layout and style for all models, for fair comparison
    # adil karsilastirma icin tum modellerde ayni duzen ve stil
    df = pd.read_excel(excel_path)
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    ax = axes[0, 0]
    ax.plot(df["epoch"], df["train_loss"], marker="o", markersize=3, label="Train")
    if df["val_loss"].notna().any():
        ax.plot(df["epoch"], df["val_loss"], marker="o", markersize=3, label="Val")
    ax.set_title("Loss"); ax.set_xlabel("Epoch"); ax.set_ylabel("Loss")
    ax.legend(); ax.grid(True, alpha=0.3)

    ax = axes[0, 1]
    ax.plot(df["epoch"], df["mAP50"], marker="o", markersize=3, label="mAP@50")
    ax.plot(df["epoch"], df["mAP50_95"], marker="o", markersize=3, label="mAP@50-95")
    ax.set_title("mAP"); ax.set_xlabel("Epoch"); ax.set_ylabel("mAP")
    ax.legend(); ax.grid(True, alpha=0.3)

    ax = axes[1, 0]
    ax.plot(df["epoch"], df["precision"], marker="o", markersize=3, color="tab:green", label="Precision")
    ax.set_title("Precision"); ax.set_xlabel("Epoch"); ax.set_ylabel("Precision")
    ax.legend(); ax.grid(True, alpha=0.3)

    ax = axes[1, 1]
    ax.plot(df["epoch"], df["recall"], marker="o", markersize=3, color="tab:red", label="Recall")
    ax.set_title("Recall"); ax.set_xlabel("Epoch"); ax.set_ylabel("Recall")
    ax.legend(); ax.grid(True, alpha=0.3)

    plt.suptitle(f"{model_name} Egitim Egrileri", fontsize=14)
    plt.tight_layout()
    plt.savefig(out_path, dpi=150, bbox_inches="tight")
    plt.show()
    return out_path

print("Ortak modul hazir.")
# Out:
# Ortak modul hazir.

# %%
# shared config, identical across YOLO11, YOLO26, RF-DETR
# ortak ayar, uc modelde ayni tutulur
COMMON = {
    'imgsz': 1024,
    'batch': 8,
    'epochs': 100,
    'patience': 20,
    'seed': 42,
}

# medical augmentation, grayscale friendly
# medikal augmentation, gri tonlamaya uygun
AUG = {
    'hsv_h': 0.0,       # no hue shift, grayscale / hue yok, gri tonlama
    'hsv_s': 0.0,       # no saturation / doygunluk yok
    'hsv_v': 0.2,       # mild brightness only / sadece hafif parlaklik
    'degrees': 5.0,     # small rotation / kucuk rotasyon
    'translate': 0.1,   # small shift / kucuk kaydirma
    'scale': 0.3,       # mild scale jitter / hafif olcek
    'fliplr': 0.5,      # horizontal flip on / yatay flip acik
    'flipud': 0.0,      # vertical flip off, anatomy / dikey flip kapali
    'mosaic': 1.0,      # mosaic on / mozaik acik
    'close_mosaic': 10, # disable mosaic last 10 epochs / son 10 epok mozaik kapali
    'mixup': 0.0,       # no mixup / mixup kapali
}
print('Ortak ayar:', COMMON)
# Out:
# Ortak ayar: {'imgsz': 1024, 'batch': 8, 'epochs': 100, 'patience': 20, 'seed': 42}

# %%
# callback maps Ultralytics metrics to standard schema and writes Excel live
# callback Ultralytics metriklerini standart semaya esler ve canli Excel yazar
def make_excel_callback(excel_path):
    def on_fit_epoch_end(trainer):
        m = trainer.metrics
        p = m.get("metrics/precision(B)")
        r = m.get("metrics/recall(B)")
        map50 = m.get("metrics/mAP50(B)")
        map5095 = m.get("metrics/mAP50-95(B)")

        # val loss from val/*_loss keys, computed by Ultralytics during validation
        # val loss, validation sirasinda Ultralytics'in hesapladigi val/*_loss anahtarlarindan
        val_parts = [m.get("val/box_loss"), m.get("val/cls_loss"), m.get("val/dfl_loss")]
        val_loss = sum(val_parts) if all(v is not None for v in val_parts) else None

        # train loss from current epoch tloss
        # train loss, mevcut epoch tloss'undan
        train_loss = None
        if trainer.tloss is not None:
            tl = trainer.tloss
            train_loss = float(tl.sum()) if hasattr(tl, "sum") else float(tl)

        row = {
            "epoch": trainer.epoch,
            "train_loss": train_loss,
            "val_loss": val_loss,
            "precision": p,
            "recall": r,
            "mAP50": map50,
            "mAP50_95": map5095,
            "f1": compute_f1(p, r),
        }
        append_epoch_row(excel_path, row)
    return on_fit_epoch_end

print("Callback hazir.")
# Out:
# Callback hazir.

# %%
from ultralytics import YOLO

# resume control: set True only if a run was interrupted and you want to continue
# resume kontrolu: sadece egitim kesildiyse ve devam etmek istiyorsan True yap
RESUME = False

# checkpoint path Ultralytics uses for resume
# Ultralytics'in resume icin kullandigi checkpoint yolu
LAST_CKPT = f'{MODEL_DIR}/{MODEL_NAME}_mass/weights/last.pt'

if RESUME:
    # continue from last checkpoint, same run
    # son checkpoint'ten devam, ayni run
    model = YOLO(LAST_CKPT)
    results = model.train(resume=True)
else:
    # fresh start from COCO pretrained weights, transfer learning
    # COCO on egitimli agirliktan temiz baslangic, transfer learning
    model = YOLO('yolo11s.pt')
    model.add_callback("on_fit_epoch_end", make_excel_callback(EXCEL_LOG))
    results = model.train(
        data=DATA_YAML,
        project=MODEL_DIR,
        name=f'{MODEL_NAME}_mass',
        exist_ok=True,
        save_period=10,   # checkpoint every 10 epochs / her 10 epokta checkpoint
        **COMMON,
        **AUG,
        plots=True,
        val=True,
    )

print('Egitim bitti.')
print('Sonuc klasoru:', results.save_dir if not RESUME else 'resume run')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 165.6MB/s 0.1s
# Ultralytics 8.4.96 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/mass_detection/yolo11s/mass_data.yaml, degrees=5.0, deterministic=True, device=, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.0, hsv_s=0.0, hsv_v=0.2, imgsz=1024, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo11s_mass, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/mass_detection/yolo11s, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/mass_detection/yolo11s/yolo11s_mass, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.3, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 143.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,428,179 parameters, 9,428,163 gradients, 21.5 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 382.8MB/s 0.0s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 3.0±5.1 ms, read: 1.4±0.5 MB/s, size: 1629.7 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/train/labels... 2671 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2671/2671 1.0it/s 43:29
# WARNING ⚠️ train: WARNING ⚠️ Failed to save cache to /content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/train/labels.cache: [Errno 30] Read-only file system: '/content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/train/labels.cache'
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 2.4±1.0 ms, read: 1.0±0.7 MB/s, size: 1308.3 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/val/labels... 333 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 333/333 1.1it/s 5:01
# WARNING ⚠️ val: WARNING ⚠️ Failed to save cache to /content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/val/labels.cache: [Errno 30] Read-only file system: '/content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/val/labels.cache'
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_mass/labels.jpg...
# Image sizes 1024 train, 1024 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_mass
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      5.17G      1.811      2.828      1.641         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.8s/it 37.8s
#                    all        333        418      0.531      0.397       0.43      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      6.03G      1.779      1.916      1.671          5       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:16
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.6s
#                    all        333        418      0.549      0.347      0.378      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      6.04G      1.732      1.875      1.636         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.2s
#                    all        333        418      0.588      0.471      0.517      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      6.04G      1.731      1.831       1.63          7       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.3s
#                    all        333        418      0.441      0.323      0.295      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      6.04G      1.677      1.717      1.603         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.1s
#                    all        333        418      0.639      0.411      0.499      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      6.04G      1.656      1.747      1.593          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.7s
#                    all        333        418      0.565      0.435      0.471       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      6.04G      1.644      1.689      1.554          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.0s
#                    all        333        418      0.622      0.476      0.536      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      6.04G      1.627      1.691      1.556         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.8s
#                    all        333        418      0.572      0.452      0.474      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      6.04G      1.606      1.634      1.551         16       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.5s
#                    all        333        418      0.514      0.352      0.371        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      6.04G       1.59      1.666      1.533         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.6s
#                    all        333        418      0.637      0.475      0.521      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      6.04G      1.592      1.614      1.528         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:25
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.1s
#                    all        333        418      0.586      0.498      0.536       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      6.04G      1.579      1.613      1.527         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.5s
#                    all        333        418      0.529      0.397      0.424      0.216
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      6.04G      1.578      1.602      1.517         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.0s
#                    all        333        418      0.612       0.49      0.547      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      6.04G      1.565      1.593      1.525         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.8s
#                    all        333        418      0.701       0.45      0.524      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      6.04G      1.561      1.588      1.523         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.4s
#                    all        333        418      0.674      0.435      0.513      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      6.04G      1.555      1.568      1.536         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418      0.653      0.469      0.562      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      6.04G      1.529      1.536      1.497          8       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:20
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418      0.662      0.483      0.554      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      6.04G      1.521      1.491      1.502          7       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.6s
#                    all        333        418      0.697      0.533      0.612      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      6.04G      1.523      1.497      1.507          7       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.8s
#                    all        333        418       0.63      0.469      0.551      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      6.04G      1.533      1.488      1.501          8       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 18.8s
#                    all        333        418      0.653      0.494      0.566      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      6.04G      1.517        1.5      1.505         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.9s
#                    all        333        418      0.628      0.492      0.544      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      6.04G      1.516      1.511      1.491         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.0s
#                    all        333        418      0.608      0.475      0.535      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      6.04G      1.502      1.442      1.498          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.0s
#                    all        333        418      0.639      0.507      0.542      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      6.04G      1.507      1.458      1.499         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.4s
#                    all        333        418      0.616      0.499      0.539      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      6.04G      1.468       1.41       1.46         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 18.7s
#                    all        333        418      0.684      0.522      0.608      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      6.04G      1.485      1.429      1.471         15       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418       0.62      0.447      0.488      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      6.04G      1.478      1.434      1.472         15       1024: 100% ━━━━━━━━━━━━ 334/334 1.3it/s 4:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418      0.703      0.499      0.593      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      6.04G      1.484        1.4      1.488         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.4s
#                    all        333        418      0.643      0.552        0.6      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      6.04G      1.477      1.415      1.476         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 20.0s
#                    all        333        418      0.684      0.491      0.601      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      6.04G      1.462      1.392      1.459         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.1s
#                    all        333        418      0.587      0.516      0.544        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      6.04G      1.467      1.404      1.464         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 22.0s
#                    all        333        418      0.675      0.512      0.601      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      6.04G      1.463      1.358      1.471         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 18.5s
#                    all        333        418       0.67      0.495      0.572      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      6.04G      1.461      1.386      1.458         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 18.9s
#                    all        333        418      0.724      0.545      0.639      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      6.04G      1.437      1.371      1.449         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 20.0s
#                    all        333        418      0.721      0.545      0.656       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      6.04G      1.433      1.355      1.447         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 23.4s
#                    all        333        418      0.706      0.562      0.668      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      6.04G      1.435      1.359      1.453         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 24.0s
#                    all        333        418      0.678      0.555      0.636      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      6.04G      1.441      1.303       1.45         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.7s
#                    all        333        418      0.724      0.529      0.615      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      6.04G      1.429       1.33      1.444          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.5s
#                    all        333        418      0.719      0.557      0.656      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      6.04G      1.418      1.307      1.418         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.5s
#                    all        333        418      0.719      0.507      0.604      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      6.04G       1.42      1.308      1.428         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.4s
#                    all        333        418      0.757      0.544      0.658      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      6.04G      1.403      1.296      1.412          8       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.6s
#                    all        333        418      0.725      0.562      0.657      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      6.04G      1.419       1.32      1.431         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 23.0s
#                    all        333        418      0.698       0.55      0.647      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      6.04G      1.375      1.235      1.405         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.9s
#                    all        333        418      0.739      0.569      0.659       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      6.04G      1.401       1.27      1.437          7       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.4s
#                    all        333        418      0.726      0.538      0.642      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      6.04G      1.374      1.247      1.404         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.6s
#                    all        333        418      0.702      0.524      0.616      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      6.04G      1.384       1.23      1.421         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.9s
#                    all        333        418      0.724      0.569      0.672       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      6.04G       1.39      1.257      1.418          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.5s
#                    all        333        418      0.674      0.634      0.681      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      6.04G      1.379      1.238       1.41          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.7s
#                    all        333        418       0.71      0.574      0.656      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      6.04G       1.37      1.254      1.405         17       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.3s
#                    all        333        418      0.743      0.567      0.662      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      6.04G       1.37      1.224      1.408         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418      0.741      0.524      0.628      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      6.04G      1.374      1.235      1.415         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 23.5s
#                    all        333        418      0.698      0.533      0.616      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      6.04G       1.38      1.218        1.4         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.8s
#                    all        333        418      0.696      0.586      0.655      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      6.04G      1.341      1.191      1.383          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.4s
#                    all        333        418      0.764      0.569      0.683      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      6.04G      1.352      1.192      1.382         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:39
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.2s
#                    all        333        418      0.711      0.591      0.668       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      6.04G      1.345       1.19      1.386         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418      0.721      0.555      0.654      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      6.04G      1.364      1.175      1.406         18       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.7s
#                    all        333        418      0.685      0.612      0.669      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      6.04G      1.346      1.161      1.391          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.4s
#                    all        333        418      0.718       0.61      0.687      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      6.04G      1.329      1.154      1.377         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.2s
#                    all        333        418      0.767      0.543      0.675      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      6.04G      1.326      1.132      1.379         16       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 23.2s
#                    all        333        418      0.714      0.593      0.675       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      6.04G      1.329      1.123      1.388          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.2s
#                    all        333        418      0.741      0.572       0.66      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      6.04G      1.295      1.115      1.348         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:33
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 23.2s
#                    all        333        418      0.676      0.644      0.703      0.392
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      6.04G      1.305      1.109      1.351         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.5s
#                    all        333        418      0.759       0.62        0.7      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      6.04G      1.306      1.116      1.357         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.6s
#                    all        333        418      0.698      0.609      0.664      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      6.04G      1.299      1.085       1.36         13       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.9s
#                    all        333        418      0.683      0.665      0.694      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      6.04G      1.305      1.093      1.358         12       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1it/s 19.1s
#                    all        333        418      0.726      0.579      0.659      0.355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      6.04G      1.317      1.095      1.359         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.3s
#                    all        333        418      0.707      0.658      0.697      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      6.04G       1.29      1.071      1.349         20       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418      0.735      0.599      0.683      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      6.04G      1.279      1.053      1.339         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 23.3s
#                    all        333        418      0.725      0.649      0.709      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      6.04G      1.269      1.028      1.342         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.1s
#                    all        333        418      0.739      0.608      0.694      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      6.04G       1.28      1.035      1.344          9       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.2s
#                    all        333        418      0.746      0.617      0.701      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      6.04G      1.281      1.045      1.345         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418      0.727      0.612       0.69      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      6.04G      1.254      1.014       1.34         10       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.9s
#                    all        333        418      0.767      0.634      0.717      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      6.04G      1.257      1.011      1.322         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 21.0s
#                    all        333        418      0.783      0.612      0.704       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      6.04G      1.252      1.002      1.327         11       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.6s
#                    all        333        418      0.736      0.612      0.684       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      6.04G      1.262       1.01      1.334         21       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.1s
#                    all        333        418      0.725      0.634      0.696      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      6.04G      1.233     0.9785      1.306          7       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:34
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.7s
#                    all        333        418      0.759      0.596      0.696      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      6.04G      1.235     0.9804      1.313         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.3s
#                    all        333        418      0.684      0.658      0.704      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      6.04G      1.217     0.9657      1.294         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 22.0s
#                    all        333        418      0.715      0.629      0.697      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      6.04G      1.234     0.9687       1.31         15       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0it/s 20.1s
#                    all        333        418      0.722      0.644        0.7      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      6.04G      1.228      0.949      1.298         14       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 22.0s
#                    all        333        418      0.765      0.616      0.708      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      6.04G      1.219     0.9543      1.299          8       1024: 100% ━━━━━━━━━━━━ 334/334 1.2it/s 4:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.1s/it 22.8s
#                    all        333        418       0.79      0.619      0.701      0.375
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 61, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 81 epochs completed in 6.643 hours.
# Optimizer stripped from /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_mass/weights/last.pt, 19.2MB
# Optimizer stripped from /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_mass/weights/best.pt, 19.2MB
#
# Validating /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_mass/weights/best.pt...
# Ultralytics 8.4.96 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.0s/it 21.5s
#                    all        333        418      0.675      0.645      0.701      0.392
# Speed: 0.5ms preprocess, 10.2ms inference, 0.0ms loss, 4.6ms postprocess per image
# Results saved to /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_mass
# Egitim bitti.
# Sonuc klasoru: /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_mass

# %%
from ultralytics import YOLO

# load the best checkpoint from training
# egitimden en iyi checkpoint'i yukle
BEST_CKPT = f'{MODEL_DIR}/{MODEL_NAME}_mass/weights/best.pt'
best_model = YOLO(BEST_CKPT)

# evaluate on the TEST split, unseen data
# TEST bolunmesinde degerlendir, gorulmemis veri
test_metrics = best_model.val(
    data=DATA_YAML,
    split='test',
    imgsz=1024,
    project=MODEL_DIR,
    name=f'{MODEL_NAME}_test',
    exist_ok=True,
    plots=True,   # saves confusion matrix and PR curve / confusion matrix ve PR egrisini kaydeder
)

# pull the four headline metrics
# dort ana metrigi al
p = test_metrics.box.mp        # mean precision
r = test_metrics.box.mr        # mean recall
map50 = test_metrics.box.map50
map5095 = test_metrics.box.map
f1 = compute_f1(p, r)

print('TEST SONUCLARI ({})'.format(MODEL_NAME))
print(f'mAP@50    : {map50:.4f}')
print(f'mAP@50-95 : {map5095:.4f}')
print(f'Precision : {p:.4f}')
print(f'Recall    : {r:.4f}')
print(f'F1-Score  : {f1:.4f}')

# save test metrics to a small summary file for the report
# rapor icin test metriklerini kucuk bir ozet dosyaya kaydet
import pandas as pd
summary = pd.DataFrame([{
    'model': MODEL_NAME,
    'mAP50': map50, 'mAP50_95': map5095,
    'precision': p, 'recall': r, 'f1': f1,
}])
summary.to_excel(f'{MODEL_DIR}/{MODEL_NAME}_test_summary.xlsx', index=False)
print('\nTest ozeti kaydedildi.')
# Out:
# Ultralytics 8.4.96 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 101 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 0.7±0.3 ms, read: 1.3±0.7 MB/s, size: 1665.8 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/test/labels... 336 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 336/336 1.1it/s 5:04
# WARNING ⚠️ val: WARNING ⚠️ Failed to save cache to /content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/test/labels.cache: [Errno 30] Read-only file system: '/content/drive/.shortcut-targets-by-id/1Wop1QGazY0vZA6leuen5xdQp1quI63OI/Kitle-Vindr&Tekno/test/labels.cache'
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 21/21 1.3s/it 27.8s
#                    all        336        400      0.748      0.637      0.693      0.382
# Speed: 6.4ms preprocess, 19.1ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_test
# TEST SONUCLARI (yolo11s)
# mAP@50    : 0.6928
# mAP@50-95 : 0.3820
# Precision : 0.7475
# Recall    : 0.6365
# F1-Score  : 0.6876
#
# Test ozeti kaydedildi.

# %%
# draw the standard 4 curves from the live Excel log
# canli Excel logundan standart 4 egriyi ciz
curves_path = f'{MODEL_DIR}/{MODEL_NAME}_curves.png'
plot_training_curves(EXCEL_LOG, curves_path, MODEL_NAME.upper())
print('Egitim egrileri kaydedildi:', curves_path)
# Out:
# Egitim egrileri kaydedildi: /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_curves.png

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from ultralytics import YOLO

# reuse best model and test paths
# en iyi modeli ve test yollarini tekrar kullan
BEST_CKPT = f'{MODEL_DIR}/{MODEL_NAME}_mass/weights/best.pt'
cm_model = YOLO(BEST_CKPT)
TEST_IMG_DIR = Path(DATASET_ROOT) / 'test' / 'images'
TEST_LBL_DIR = Path(DATASET_ROOT) / 'test' / 'labels'


def iou_xywh(b1, b2):
    # IoU of two normalized xywh boxes
    # iki normalize xywh kutunun IoU'su
    def corners(b):
        x, y, w, h = b
        return [x-w/2, y-h/2, x+w/2, y+h/2]
    a, b = corners(b1), corners(b2)
    inter = max(0, min(a[2], b[2])-max(a[0], b[0])) * max(0, min(a[3], b[3])-max(a[1], b[1]))
    ua = (a[2]-a[0])*(a[3]-a[1]) + (b[2]-b[0])*(b[3]-b[1]) - inter
    return inter/ua if ua > 0 else 0


def load_gt(stem):
    # read ground truth boxes
    # gercek kutulari oku
    lp = TEST_LBL_DIR / f'{stem}.txt'
    gts = []
    if lp.exists():
        for line in open(lp):
            parts = line.split()
            if len(parts) >= 5:
                gts.append([float(x) for x in parts[1:5]])
    return gts


# accumulate TP, FP, FN over the whole test set
# tum test seti uzerinde TP, FP, FN topla
TP = FP = FN = 0
IOU_THR = 0.5
CONF_THR = 0.25

all_imgs = sorted(TEST_IMG_DIR.glob('*.png'))
for ip in all_imgs:
    res = cm_model.predict(str(ip), imgsz=1024, conf=CONF_THR, verbose=False)[0]
    preds = []
    if res.boxes is not None and len(res.boxes) > 0:
        preds = [list(b) for b in res.boxes.xywhn.cpu().numpy()]
    gts = load_gt(ip.stem)

    matched = set()
    for pb in preds:
        best, bj = 0, -1
        for j, gb in enumerate(gts):
            if j in matched:
                continue
            i = iou_xywh(pb, gb)
            if i > best:
                best, bj = i, j
        if best >= IOU_THR:
            TP += 1
            matched.add(bj)
        else:
            FP += 1
    FN += len(gts) - len(matched)

print(f'TP={TP}  FP={FP}  FN={FN}')

# 2x2 matrix: rows predicted (mass/background), cols actual (mass/background)
# 2x2 matris: satir tahmin (mass/background), sutun gercek (mass/background)
# background-background is undefined in detection, shown as 0
# detection'da background-background tanimsiz, 0 gosterilir
cm = np.array([[TP, FP],
               [FN, 0]])

fig, ax = plt.subplots(figsize=(6, 5))
im = ax.imshow(cm, cmap='Blues')

labels = ['mass', 'background']
ax.set_xticks([0, 1]); ax.set_yticks([0, 1])
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
ax.set_xlabel('Gercek (Actual)')
ax.set_ylabel('Tahmin (Predicted)')
ax.set_title(f'{MODEL_NAME.upper()} Confusion Matrix (Test, IoU={IOU_THR})')

# write counts inside cells
# hucre icine sayilari yaz
for i in range(2):
    for j in range(2):
        val = cm[i, j]
        color = 'white' if val > cm.max()/2 else 'black'
        ax.text(j, i, str(val), ha='center', va='center', color=color, fontsize=14)

plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
plt.tight_layout()
cm_path = f'{MODEL_DIR}/{MODEL_NAME}_confusion_matrix.png'
plt.savefig(cm_path, dpi=150, bbox_inches='tight')
plt.show()

# quick sanity: precision and recall from matrix should match test metrics
# hizli kontrol: matristen precision ve recall test metrikleriyle uyusmali
prec = TP/(TP+FP) if (TP+FP) > 0 else 0
rec = TP/(TP+FN) if (TP+FN) > 0 else 0
print(f'Matristen: Precision={prec:.3f}  Recall={rec:.3f}')
print('Kaydedildi:', cm_path)
# Out:
# TP=274  FP=169  FN=126
# Matristen: Precision=0.619  Recall=0.685
# Kaydedildi: /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_confusion_matrix.png

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
from pathlib import Path
from ultralytics import YOLO

# load best model, force to GPU, enable gradients
# en iyi modeli yukle, GPU'ya sabitle, gradyanlari ac
BEST_CKPT = f'{MODEL_DIR}/{MODEL_NAME}_mass/weights/best.pt'
gc_model = YOLO(BEST_CKPT)

device = 'cuda' if torch.cuda.is_available() else 'cpu'
tm = gc_model.model.to(device)
tm.eval()
for p in tm.parameters():
    p.requires_grad_(True)

# Grad-CAM settings
# Grad-CAM ayarlari
CAM_THRESH = 0.25  # tissue-masked, logit-based CAM / doku maskeli, logit tabanli CAM
TEST_IMG_DIR = Path(DATASET_ROOT) / 'test' / 'images'
TEST_LBL_DIR = Path(DATASET_ROOT) / 'test' / 'labels'


def iou_xywh(b1, b2):
    def corners(b):
        x, y, w, h = b
        return [x-w/2, y-h/2, x+w/2, y+h/2]
    a, b = corners(b1), corners(b2)
    inter = max(0, min(a[2], b[2])-max(a[0], b[0])) * max(0, min(a[3], b[3])-max(a[1], b[1]))
    ua = (a[2]-a[0])*(a[3]-a[1]) + (b[2]-b[0])*(b[3]-b[1]) - inter
    return inter/ua if ua > 0 else 0


def load_gt(stem):
    lp = TEST_LBL_DIR / f'{stem}.txt'
    gts = []
    if lp.exists():
        for line in open(lp):
            parts = line.split()
            if len(parts) >= 5:
                gts.append([float(x) for x in parts[1:5]])
    return gts


def categorize(img_path):
    # label image as clean / missed / false alarm using IoU matching
    # IoU eslestirme ile goruntuyu temiz / kacirilan / yanlis alarm diye etiketle
    res = gc_model.predict(str(img_path), imgsz=1024, conf=0.25, verbose=False)[0]
    preds = [list(b) for b in res.boxes.xywhn.cpu().numpy()] if (res.boxes is not None and len(res.boxes) > 0) else []
    gts = load_gt(img_path.stem)
    matched = set(); tp = 0
    for pb in preds:
        best, bj = 0, -1
        for j, gb in enumerate(gts):
            if j in matched:
                continue
            i = iou_xywh(pb, gb)
            if i > best:
                best, bj = i, j
        if best >= 0.5:
            tp += 1; matched.add(bj)
    fp = len(preds) - tp
    fn = len(gts) - len(matched)
    if tp > 0 and fp == 0 and fn == 0:
        return 'dogru'
    elif fp > 0 and tp == 0:
        return 'yanlis_alarm'
    elif fn > 0 and tp == 0:
        return 'kacirilan'
    return 'karisik'

def compute_overlay(img_path):
    # Targeted Grad-CAM: backprop from the P3 cell at the detected/true box center
    # Hedefli Grad-CAM: tespit/gercek kutu merkezindeki P3 hucresinden geri yay
    tm.to(device)

    # first get the model's detections for this image
    # once bu goruntu icin modelin tespitlerini al
    res = gc_model.predict(str(img_path), imgsz=1024, conf=0.25, verbose=False)[0]
    det_boxes = res.boxes.xywhn.cpu().numpy() if (res.boxes is not None and len(res.boxes) > 0) else []
    gts = load_gt(img_path.stem)

    # choose target box center: detection if available, else ground truth
    # hedef kutu merkezi sec: varsa tespit, yoksa gercek tumor
    if len(det_boxes) > 0:
        # most confident detection center
        # en guvenli tespitin merkezi
        confs = res.boxes.conf.cpu().numpy()
        bx = det_boxes[confs.argmax()]
        target_cx, target_cy = float(bx[0]), float(bx[1])
    elif len(gts) > 0:
        # missed case: use the true tumor center
        # kacirilan durum: gercek tumor merkezini kullan
        target_cx, target_cy = gts[0][0], gts[0][1]
    else:
        target_cx, target_cy = 0.5, 0.5

    img_bgr = cv2.imread(str(img_path))
    img_r = cv2.resize(img_bgr, (1024, 1024))
    x = torch.from_numpy(img_r[:, :, ::-1].copy()).permute(2, 0, 1).float() / 255.0
    x = x.unsqueeze(0).to(device)
    x.requires_grad_(True)

    # hooks: layer 16 activations + P3 logits
    # hook: layer 16 aktivasyon + P3 logit
    cam_store = {}
    def cam_hook(m, i, o):
        o.retain_grad()
        cam_store['out'] = o
    h_cam = tm.model[16].register_forward_hook(cam_hook)
    logit_store = {}
    def logit_hook(m, i, o):
        logit_store['out'] = o
    h_logit = tm.model[-1].cv3[0].register_forward_hook(logit_hook)

    with torch.enable_grad():
        tm.zero_grad()
        _ = tm(x)
        logits = logit_store['out']            # [1, nc, H, W]
        _, nc, Hh, Ww = logits.shape
        # map target box center to the P3 grid cell
        # hedef kutu merkezini P3 izgara hucresine esle
        gx = min(int(target_cx * Ww), Ww - 1)
        gy = min(int(target_cy * Hh), Hh - 1)
        # backprop from that specific cell's logit
        # o belirli hucrenin logit'inden geri yay
        target = logits[0, :, gy, gx].sum()
        target.backward()

    A = cam_store['out'].detach()
    G = cam_store['out'].grad
    w = G.mean(dim=[2, 3], keepdim=True)
    cam = torch.relu((w * A).sum(dim=1)).squeeze().cpu().numpy()
    if cam.max() > cam.min():
        cam = (cam - cam.min()) / (cam.max() - cam.min())
    h_cam.remove()
    h_logit.remove()

    cam_r = cv2.resize(cam.astype('float32'), (1024, 1024))
    cam_r = cv2.GaussianBlur(cam_r, (0, 0), sigmaX=20)
    if cam_r.max() > 0:
        cam_r = cam_r / cam_r.max()

    # tissue mask
    # doku maskesi
    gray = cv2.cvtColor(img_r, cv2.COLOR_BGR2GRAY)
    tissue = (gray > 15).astype('float32')
    cam_r = cam_r * tissue

    hm = cv2.applyColorMap(np.uint8(255 * cam_r), cv2.COLORMAP_JET)
    blended = cv2.addWeighted(img_r, 0.6, hm, 0.4, 0)
    mask = (cam_r >= CAM_THRESH)[:, :, None]
    overlay = np.where(mask, blended, img_r).astype(np.uint8)

    # draw ground truth tumor boxes in bright green
    # gercek tumor kutularini parlak yesil ciz
    for (cx, cy, bw, bh) in gts:
        x1 = int((cx - bw/2) * 1024)
        y1 = int((cy - bh/2) * 1024)
        x2 = int((cx + bw/2) * 1024)
        y2 = int((cy + bh/2) * 1024)
        cv2.rectangle(overlay, (x1, y1), (x2, y2), (0, 255, 0), 3)

    return overlay

# scan test images, bucket by category
# test goruntulerini tara, kategoriye ayir
all_imgs = sorted(TEST_IMG_DIR.glob('*.png'))
buckets = {'dogru': [], 'kacirilan': [], 'yanlis_alarm': [], 'karisik': []}
for ip in all_imgs[:120]:
    buckets[categorize(ip)].append(ip)

# pick 9: mix of correct and error cases
# 9 sec: dogru ve hatali durum karisimi
selected = []
selected += [(p, 'Dogru') for p in buckets['dogru'][:4]]
selected += [(p, 'Kacirilan') for p in buckets['kacirilan'][:3]]
selected += [(p, 'Yanlis Alarm') for p in buckets['yanlis_alarm'][:2]]
while len(selected) < 9 and buckets['karisik']:
    selected.append((buckets['karisik'].pop(0), 'Karisik'))
selected = selected[:9]

print(f'Secilen ornek: {len(selected)}')
for p, lab in selected:
    print(f'  {lab}: {p.name}')

# 3x3 grid
# 3x3 grid
fig, axes = plt.subplots(3, 3, figsize=(16, 16))
for ax, (ip, lab) in zip(axes.flat, selected):
    ov = compute_overlay(ip)
    ax.imshow(cv2.cvtColor(ov, cv2.COLOR_BGR2RGB))
    ax.set_title(lab, fontsize=12)
    ax.axis('off')
for ax in axes.flat[len(selected):]:
    ax.axis('off')

plt.suptitle(f'{MODEL_NAME.upper()} Grad-CAM Analizi', fontsize=16)
plt.tight_layout()
gradcam_path = f'{MODEL_DIR}/{MODEL_NAME}_gradcam.png'
plt.savefig(gradcam_path, dpi=150, bbox_inches='tight')
plt.show()
print('Grad-CAM kaydedildi:', gradcam_path)
# Out:
# Secilen ornek: 9
#   Dogru: 032ab9e0ecd5fd673517ffa3eb805d15.png
#   Dogru: 058e5f91678b4d3dac39bf1b6a798a22.png
#   Dogru: 0734a9dc7d6d89e8c91458545afeef9d.png
#   Dogru: 0d0826dc6e633a7729ea56fa7390c508.png
#   Kacirilan: 00be38a5c0566291168fe381ba0028e6.png
#   Kacirilan: 11088_RMLO.png
#   Kacirilan: 11134_RMLO.png
#   Yanlis Alarm: 0c19be554e27e2fdc2fe05ad954e825c.png
#   Yanlis Alarm: 11041_RCC.png
# Grad-CAM kaydedildi: /content/drive/MyDrive/mass_detection/yolo11s/yolo11s_gradcam.png
